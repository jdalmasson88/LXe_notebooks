# %%
from TMSAnalysis.WaveformAnalysis import Waveform
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [10, 8]
plt.rcParams['font.size'] = 12

# %% [markdown]
# In this script I quickly check for corrupted tier1 file.  It is possible to see how some events are missing (from event 79 on), those are the corrupted ones. In this case the reduced file is not present so in the plot energy are risetime are not shown

# %%
fname = '/p/lustre1/jacopod/29th/20200211_AfterRecirculation/tier1/tier1_SIS3316Raw_20200210211206_SiPMs_longTPC_sbias32_scope_trig13_36mV_cath_6kV_1-ngm.root'
run_parameters_file = '/g/g90/jacopod/software/TMSAnalysis/config/Run_Parameters_Xe_Run29.csv'
calibrations_file = '/g/g90/jacopod/software/TMSAnalysis/config/Calibrations_Xe_Run11b.csv'
channel_map_file = '/g/g90/jacopod/software/TMSAnalysis/config/Channel_Map_Xe_Run29.csv'
for i in range(70,85):
    event = Waveform.Event('/p/lustre1/jacopod/29th/analysis_500ns/20200213_AfterRnInjection/reduced_added.h5',\
                           '/p/lustre1/jacopod/29th/20200213_AfterRnInjection/tier1/',i,\
                       run_parameters_file,\
                       calibrations_file,\
                       channel_map_file)
    
    event.smooth(0.5)
    plot = event.plot_event()
    plot.show()
